# %%
#Importing dependencies
import pandas as pd
import numpy as np

# %%
#Creating file paths for 2019-2021 
file2019_1 = ("Resources/Original/JC-201901-citibike-tripdata.csv")
file2019_2 =("Resources/Original/JC-201902-citibike-tripdata.csv")
file2019_3 =("Resources/Original/JC-201903-citibike-tripdata.csv")
file2019_4 = ("Resources/Original/JC-201904-citibike-tripdata.csv")
file2019_5 = ("Resources/Original/JC-201905-citibike-tripdata.csv")
file2019_6 = ("Resources/Original/JC-201906-citibike-tripdata.csv")
file2019_7 = ("Resources/Original/JC-201907-citibike-tripdata.csv")
file2019_8 = ("Resources/Original/JC-201908-citibike-tripdata.csv")
file2019_9 = ("Resources/Original/JC-201909-citibike-tripdata.csv")
file2019_10 = ("Resources/Original/JC-201910-citibike-tripdata.csv")
file2019_11 = ("Resources/Original/JC-201911-citibike-tripdata.csv")
file2019_12 = ("Resources/Original/JC-201912-citibike-tripdata.csv")
file2020_1 = ("Resources/Original/JC-202001-citibike-tripdata.csv") 
file2020_2 = ("Resources/Original/JC-202002-citibike-tripdata.csv")
file2020_3 = ("Resources/Original/JC-202003-citibike-tripdata.csv")
file2020_4 = ("Resources/Original/JC-202004-citibike-tripdata.csv")
file2020_5 = ("Resources/Original/JC-202005-citibike-tripdata.csv")
file2020_6 = ("Resources/Original/JC-202006-citibike-tripdata.csv")
file2020_7 = ("Resources/Original/JC-202007-citibike-tripdata.csv")
file2020_8 = ("Resources/Original/JC-202008-citibike-tripdata.csv")
file2020_9 = ("Resources/Original/JC-202009-citibike-tripdata.csv")
file2020_10 = ("Resources/Original/JC-202010-citibike-tripdata.csv")
file2020_11 = ("Resources/Original/JC-202011-citibike-tripdata.csv")
file2020_12 = ("Resources/Original/JC-202012-citibike-tripdata.csv")
# file2021_1 = ("Resources/JC-202101-citibike-tripdata.csv")
# file2021_2 = ("Resources/JC-202102-citibike-tripdata.csv")
# file2021_3 = ("Resources/JC-202103-citibike-tripdata.csv")
# file2021_4 = ("Resources/JC-202104-citibike-tripdata.csv")
# file2021_5 = ("Resources/JC-202105-citibike-tripdata.csv")

# %%
#Reading the 2019 files to jupyterlabNotebook
df2019_1 = pd.read_csv(file2019_1)
df2019_2 = pd.read_csv(file2019_2)
df2019_3 = pd.read_csv(file2019_3)
df2019_4 = pd.read_csv(file2019_4)
df2019_5 = pd.read_csv(file2019_5)
df2019_6 = pd.read_csv(file2019_6)
df2019_7 = pd.read_csv(file2019_7)
df2019_8 = pd.read_csv(file2019_8)
df2019_9 = pd.read_csv(file2019_9)
df2019_10 = pd.read_csv(file2019_10)
df2019_11 = pd.read_csv(file2019_11)
df2019_12 = pd.read_csv(file2019_12)
#Reading the 2020 files to jupyterlabNotebook
df2020_1 = pd.read_csv(file2020_1)
df2020_2 = pd.read_csv(file2020_2)
df2020_3 = pd.read_csv(file2020_3)
df2020_4 = pd.read_csv(file2020_4)
df2020_5 = pd.read_csv(file2020_5)
df2020_6 = pd.read_csv(file2020_6)
df2020_7 = pd.read_csv(file2020_7)
df2020_8 = pd.read_csv(file2020_8)
df2020_9 = pd.read_csv(file2020_9)
df2020_10 = pd.read_csv(file2020_10)
df2020_11 = pd.read_csv(file2020_11)
df2020_12 = pd.read_csv(file2020_12)
#Reading the 2021 files to jupyterlabNotebook
# df2021_1 = pd.read_csv(file2021_1)
# df2021_2 = pd.read_csv(file2021_2)
# df2021_3 = pd.read_csv(file2021_3)
# df2021_4 = pd.read_csv(file2021_4)
# df2021_5 = pd.read_csv(file2021_5)

# %%
#combing the df per year first (2019)
frames = [df2019_1,
df2019_2,
df2019_3,
df2019_4,
df2019_5,
df2019_6,
df2019_7,
df2019_8,
df2019_9,
df2019_10,
df2019_11,
df2019_12,
]
df2019 = pd.concat(frames)
df2019.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1           505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2           756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3          1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4          1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3214    Essex Light Rail
# ...

# %%
compression_opts5 = dict(method='zip',
                        archive_name='OGYear2019.csv')  
df2019.to_csv('Resources/zip/OG2019.zip', index=False,
          compression=compression_opts5)

# %%
#Splitting the df's date and start time 
df2019[['Start_Date','Start_Time']] = df2019.starttime.str.split(" ", expand=True)
df2019[['End_Date','End_Time']] = df2019.stoptime.str.split(" ", expand=True)
df2019.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1           505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2           756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3          1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4          1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3214    Essex Light Rail
# ...

# %%
#Delete extra columns
final2019df = df2019.drop(columns=['starttime', 'stoptime'])
final2019df.head()
# Out:
#    tripduration  start station id start station name  start station latitude  \
# 0           201              3183     Exchange Place               40.716247
# 1           505              3183     Exchange Place               40.716247
# 2           756              3183     Exchange Place               40.716247
# 3          1575              3183     Exchange Place               40.716247
# 4          1566              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3214    Essex Light Rail
# 1               -74.033459            3638       Washington St
# 2               -74.033459            3192  Liberty Light Rail
# 3               -74.033459            3638       Washington St
# 4               -74.033459            3638       Washington St
#
#    end station latitude  end station longitude  bikeid    usertype  \
# ...

# %%
#Shifiting coumns to be in order 
one = final2019df.pop('End_Time')

final2019df.insert(1,'End_Time', one)

# %%
#Shifiting coumns to be in order 
two = final2019df.pop('Start_Time')

final2019df.insert(1,'Start_Time', two)

# %%
#Shifiting coumns to be in order 
three = final2019df.pop('End_Date')

final2019df.insert(1,'End_Date', three)

# %%
#Shifiting coumns to be in order 
four = final2019df.pop('Start_Date')

final2019df.insert(1,'Start_Date', four)

# %%
final_2019_df = final2019df.rename(columns={'tripduration':'Trip_Duration',
                        'start station id': 'Start_Station_Id', 
                        'start station name':'Start_Station_Name',
                        'start station latitude':'Start_Station_Latitude',
                        'start station longitude': 'Start_Station_Longitude',
                        'end station id':'End_station_Id',
                        'end station name':'End_Station_Name',
                        'end station latitude':'End_Station_Latitude',
                        'end station longitude': 'End_Station_Longitude',
                        'bikeid': 'Bike_Id',
                        'usertype': 'User_Type',
                        'birth year':'Birth_Year',
                        'gender':'Gender'
                       })
final_2019_df.head()
# Out:
#    Trip_Duration  Start_Date    End_Date     Start_Time       End_Time  \
# 0            201  2019-01-01  2019-01-01  03:09:09.7110  03:12:30.8790
# 1            505  2019-01-01  2019-01-01  05:18:00.1060  05:26:25.9050
# 2            756  2019-01-01  2019-01-01  10:36:33.3400  10:49:10.2600
# 3           1575  2019-01-01  2019-01-01  12:43:38.6430  13:09:54.5280
# 4           1566  2019-01-01  2019-01-01  12:43:39.6010  13:09:46.5100
#
#    Start_Station_Id Start_Station_Name  Start_Station_Latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    Start_Station_Longitude  End_station_Id    End_Station_Name  \
# 0               -74.033459            3214    Essex Light Rail
# ...

# %%
#combing the df per year first (2020)
frames = [df2020_1,
df2020_2,
df2020_3,
df2020_4,
df2020_5,
df2020_6,
df2020_7,
df2020_8,
df2020_9,
df2020_10,
df2020_11,
df2020_12,
]
df2020 = pd.concat(frames)
df2020.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1           377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2           288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3           435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4           231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3195            Sip Ave               40.730897
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id  end station name  \
# 0               -74.043117            3211        Newark Ave
# ...

# %%
compression_opts6 = dict(method='zip',
                        archive_name='OGYear2020.csv')  
df2020.to_csv('Resources/zip/OG2020.zip', index=False,
          compression=compression_opts6)

# %%
#Merging both full years togheter
fram = [df2019, df2020]
df12 = pd.concat(fram)
#Checking the final df 
df12
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1               505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2               756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3              1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4              1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
# ...             ...                       ...                       ...
# 11689          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 11690          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 11691          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 11692           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 11693          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#        start station id start station name  start station latitude  \
# ...

# %%
compression_opts7 = dict(method='zip',
                        archive_name='OGYear2019.csv')  
df2019.to_csv('Resources/zip/OG2019.zip', index=False,
          compression=compression_opts7)

# %%
#Splitting the df's date and start time 
df2020[['Start_Date','Start_Time']] = df2020.starttime.str.split(" ", expand=True)
df2020[['End_Date','End_Time']] = df2020.stoptime.str.split(" ", expand=True)
df2020.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1           377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2           288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3           435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4           231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3195            Sip Ave               40.730897
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id  end station name  \
# 0               -74.043117            3211        Newark Ave
# ...

# %%
#Delete extra columns
final2020df = df2020.drop(columns=['starttime', 'stoptime'])
final2020df.head()
# Out:
#    tripduration  start station id start station name  start station latitude  \
# 0           226              3186      Grove St PATH               40.719586
# 1           377              3186      Grove St PATH               40.719586
# 2           288              3186      Grove St PATH               40.719586
# 3           435              3195            Sip Ave               40.730897
# 4           231              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id  end station name  \
# 0               -74.043117            3211        Newark Ave
# 1               -74.043117            3269   Brunswick & 6th
# 2               -74.043117            3269   Brunswick & 6th
# 3               -74.063913            3280       Astor Place
# 4               -74.043117            3276  Marin Light Rail
#
#    end station latitude  end station longitude  bikeid    usertype  \
# ...

# %%
#Shifiting coumns to be in order 
one = final2020df.pop('End_Time')

final2020df.insert(1,'End_Time', one)

# %%
#Shifiting coumns to be in order 
two = final2020df.pop('Start_Time')

final2020df.insert(1,'Start_Time', two)

# %%
#Shifiting coumns to be in order 
three = final2020df.pop('End_Date')

final2020df.insert(1,'End_Date', three)

# %%
#Shifiting coumns to be in order 
four = final2020df.pop('Start_Date')

final2020df.insert(1,'Start_Date', four)

# %%
final_2020_df = final2020df.rename(columns={'tripduration':'Trip_Duration',
                        'start station id': 'Start_Station_Id', 
                        'start station name':'Start_Station_Name',
                        'start station latitude':'Start_Station_Latitude',
                        'start station longitude': 'Start_Station_Longitude',
                        'end station id':'End_station_Id',
                        'end station name':'End_Station_Name',
                        'end station latitude':'End_Station_Latitude',
                        'end station longitude': 'End_Station_Longitude',
                        'bikeid': 'Bike_Id',
                        'usertype': 'User_Type',
                        'birth year':'Birth_Year',
                        'gender':'Gender'
                       })
final_2020_df.head()
# Out:
#    Trip_Duration  Start_Date    End_Date     Start_Time       End_Time  \
# 0            226  2020-01-01  2020-01-01  00:04:50.1920  00:08:37.0370
# 1            377  2020-01-01  2020-01-01  00:16:01.6700  00:22:19.0800
# 2            288  2020-01-01  2020-01-01  00:17:33.8770  00:22:22.4420
# 3            435  2020-01-01  2020-01-01  00:32:05.9020  00:39:21.0660
# 4            231  2020-01-01  2020-01-01  00:46:19.6780  00:50:11.3440
#
#    Start_Station_Id Start_Station_Name  Start_Station_Latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3195            Sip Ave               40.730897
# 4              3186      Grove St PATH               40.719586
#
#    Start_Station_Longitude  End_station_Id  End_Station_Name  \
# 0               -74.043117            3211        Newark Ave
# ...

# %%
#Merging both full years togheter
final_frames = [df2019, df2020]
df = pd.concat(final_frames)
#Checking the final df 
df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1               505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2               756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3              1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4              1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
# ...             ...                       ...                       ...
# 11689          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 11690          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 11691          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 11692           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 11693          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#        start station id start station name  start station latitude  \
# ...

# %%
df1 = df.copy()

# %%
#Loading df into csvs for exploration 
#2019
compression_opts1 = dict(method='zip',
                        archive_name='Year2019.csv')  
final_2019_df.to_csv('Resources/zip/2019.zip', index=False,
          compression=compression_opts1)   
#2020
compression_opts2 = dict(method='zip',
                        archive_name='Year2020.csv')  
final_2020_df.to_csv('Resources/zip/2020.zip', index=False,
          compression=compression_opts2)

# %%
#Splitting the df's date and start time 
df1[['Start_Date','Start_Time']] = df1.starttime.str.split(" ", expand=True)
df1[['End_Date','End_Time']] = df1.stoptime.str.split(" ", expand=True)
df1.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1           505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2           756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3          1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4          1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3214    Essex Light Rail
# ...

# %%
finaldf = df1.drop(columns=['starttime', 'stoptime'])
finaldf.head()
# Out:
#    tripduration  start station id start station name  start station latitude  \
# 0           201              3183     Exchange Place               40.716247
# 1           505              3183     Exchange Place               40.716247
# 2           756              3183     Exchange Place               40.716247
# 3          1575              3183     Exchange Place               40.716247
# 4          1566              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3214    Essex Light Rail
# 1               -74.033459            3638       Washington St
# 2               -74.033459            3192  Liberty Light Rail
# 3               -74.033459            3638       Washington St
# 4               -74.033459            3638       Washington St
#
#    end station latitude  end station longitude  bikeid    usertype  \
# ...

# %%
#Shifiting coumns to be in order 
one = finaldf.pop('End_Time')

finaldf.insert(1,'End_Time', one)

# %%
#Shifiting coumns to be in order 
two = finaldf.pop('Start_Time')

finaldf.insert(1,'Start_Time', two)

# %%
#Shifiting coumns to be in order 
three = finaldf.pop('End_Date')

finaldf.insert(1,'End_Date', three)

# %%
#Shifiting coumns to be in order 
four = finaldf.pop('Start_Date')

finaldf.insert(1,'Start_Date', four)

# %%
finaldf.head()
# Out:
#    tripduration  Start_Date    End_Date     Start_Time       End_Time  \
# 0           201  2019-01-01  2019-01-01  03:09:09.7110  03:12:30.8790
# 1           505  2019-01-01  2019-01-01  05:18:00.1060  05:26:25.9050
# 2           756  2019-01-01  2019-01-01  10:36:33.3400  10:49:10.2600
# 3          1575  2019-01-01  2019-01-01  12:43:38.6430  13:09:54.5280
# 4          1566  2019-01-01  2019-01-01  12:43:39.6010  13:09:46.5100
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3214    Essex Light Rail
# ...

# %%
finaldf.columns
# Out:
# Index(['tripduration', 'Start_Date', 'End_Date', 'Start_Time', 'End_Time',
#        'start station id', 'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
final_df = finaldf.rename(columns={'tripduration':'Trip_Duration',
                        'start station id': 'Start_Station_Id', 
                        'start station name':'Start_Station_Name',
                        'start station latitude':'Start_Station_Latitude',
                        'start station longitude': 'Start_Station_Longitude',
                        'end station id':'End_station_Id',
                        'end station name':'End_Station_Name',
                        'end station latitude':'End_Station_Latitude',
                        'end station longitude': 'End_Station_Longitude',
                        'bikeid': 'Bike_Id',
                        'usertype': 'User_Type',
                        'birth year':'Birth_Year',
                        'gender':'Gender'
                       })
final_df.head()
# Out:
#    Trip_Duration  Start_Date    End_Date     Start_Time       End_Time  \
# 0            201  2019-01-01  2019-01-01  03:09:09.7110  03:12:30.8790
# 1            505  2019-01-01  2019-01-01  05:18:00.1060  05:26:25.9050
# 2            756  2019-01-01  2019-01-01  10:36:33.3400  10:49:10.2600
# 3           1575  2019-01-01  2019-01-01  12:43:38.6430  13:09:54.5280
# 4           1566  2019-01-01  2019-01-01  12:43:39.6010  13:09:46.5100
#
#    Start_Station_Id Start_Station_Name  Start_Station_Latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    Start_Station_Longitude  End_station_Id    End_Station_Name  \
# 0               -74.033459            3214    Essex Light Rail
# ...

# %%
#Changing the types of the data frame
final_df[['Start_Date','End_Date']] = final_df[['Start_Date','End_Date']].apply(pd.to_datetime)

# %%
final_df.dtypes
# Out:
# Trip_Duration                       int64
# Start_Date                 datetime64[ns]
# End_Date                   datetime64[ns]
# Start_Time                         object
# End_Time                           object
# Start_Station_Id                    int64
# Start_Station_Name                 object
# Start_Station_Latitude            float64
# Start_Station_Longitude           float64
# End_station_Id                      int64
# End_Station_Name                   object
# End_Station_Latitude              float64
# End_Station_Longitude             float64
# Bike_Id                             int64
# User_Type                          object
# Birth_Year                          int64
# Gender                              int64
# dtype: object

# %%
final_df.head()
# Out:
#    Trip_Duration Start_Date   End_Date     Start_Time       End_Time  \
# 0            201 2019-01-01 2019-01-01  03:09:09.7110  03:12:30.8790
# 1            505 2019-01-01 2019-01-01  05:18:00.1060  05:26:25.9050
# 2            756 2019-01-01 2019-01-01  10:36:33.3400  10:49:10.2600
# 3           1575 2019-01-01 2019-01-01  12:43:38.6430  13:09:54.5280
# 4           1566 2019-01-01 2019-01-01  12:43:39.6010  13:09:46.5100
#
#    Start_Station_Id Start_Station_Name  Start_Station_Latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    Start_Station_Longitude  End_station_Id    End_Station_Name  \
# 0               -74.033459            3214    Essex Light Rail
# ...

# %%
#final DF to CSV
compression_opts4 = dict(method='zip',
                        archive_name='Merged2019-2020.csv')  
final_df.to_csv('Resources/zip/final.zip', index=False,
          compression=compression_opts4)
